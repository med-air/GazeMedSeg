# %%
import os
import glob
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import pydensecrf.densecrf as dcrf
from tqdm import tqdm
from pydensecrf.utils import unary_from_softmax

# %%
root = "/media/yesindeed/DATADRIVE1/data/Kvasir-SEG"

# df_train = pd.read_csv(
#     os.path.join(root, "train.txt"), sep=" ", header=None, names=["img_id"]
# )
# # df_val = pd.read_csv(os.path.join(root, "val.txt"), sep=" ", header=None, names=["img_id"])
# df_test = pd.read_csv(
#     os.path.join(root, "test.txt"), sep=" ", header=None, names=["img_id"]
# )
# df_images = pd.concat([df_train, df_test], axis=0).reset_index(drop=True)
# df_images

# %%
def crf_inference(img, probs, t=10, scale_factor=1, compat=1.5):
    h, w = probs.shape

    probs = probs[None, :, :]
    probs = np.concatenate([1 - probs, probs], axis=0)

    d = dcrf.DenseCRF2D(w, h, 2)
    # unary = fake_prob.reshape((2, -1))
    unary = unary_from_softmax(probs)
    # unary = np.ascontiguousarray(unary)

    d.setUnaryEnergy(unary)
    # d.addPairwiseGaussian(3/scale_factor, compat=10)
    d.addPairwiseBilateral(sxy=80 / scale_factor, srgb=13, rgbim=np.copy(img), compat=compat)

    Q = d.inference(t)
    # crf = np.argmax(Q, axis=0).reshape((h, w))
    crf = np.array(Q)[1].reshape((h, w))

    return crf

# %%
def compute_dice(pred, gt):
    inter = np.sum(pred * gt)

    dice = 2 * inter / (np.sum(pred) + np.sum(gt) + 1e-6)

    return dice

# %%
annotator = "yq"
scale_factor = 1
t = 10
compat = 1

target = 1
# target_id = "cju2iatlki5u309930zmgkv6h"
target_id = "cju0roawvklrq0799vmjorwfv"

# dice_l = {}

# for i, path in tqdm(enumerate(df_images["img_id"].tolist())):
for i, path in tqdm(enumerate(glob.glob(os.path.join(root, "gaze", f"heatmap_{annotator}", "*.jpg")))):
    path = os.path.basename(path).split(".")[0]

    # if path != target_id:
    #     continue
    # if i != target:
    #     continue
    img = np.array(Image.open(os.path.join(root, "images", f"{path}.jpg")).convert("RGB"))
    gt = np.array(Image.open(os.path.join(root, "masks", f"{path}.jpg")).convert("L"))

    heatmap = Image.open(os.path.join(root, "gaze", f"heatmap_{annotator}", f"{path}.jpg")).convert("L")
    heatmap = np.array(heatmap).astype(np.float32) / 255

    crf_map = crf_inference(img, heatmap, t=t, scale_factor=1, compat=compat)
    save_folder = os.path.join(root, "gaze", f"crf_compat{compat}_{annotator}")
    if not os.path.exists(save_folder):
        os.makedirs(save_folder)

    # dice = compute_dice(crf_map > 0.5, gt.astype(np.float32) / 255)
    # dice_l[path] = dice

    crf_map_img = Image.fromarray((crf_map * 255).astype(np.uint8))
    crf_map_img.save(os.path.join(save_folder, f"{path}.jpg"))

    # np.save(os.path.join(save_folder, f"{path}.npy"), crf_map.astype(np.float16))
# Out:
# 0it [00:00, ?it/s]
# 110it [00:53,  2.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=22'>23</a> heatmap = Image.open(os.path.join(root, "gaze", f"heatmap_{annotator}", f"{path}.jpg")).convert("L")
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=23'>24</a> heatmap = np.array(heatmap).astype(np.float32) / 255
# ---> <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> crf_map = crf_inference(img, heatmap, t=t, scale_factor=1, compat=compat)
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a> save_folder = os.path.join(root, "gaze", f"crf_compat{compat}_{annotator}")
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> if not os.path.exists(save_folder):
#
# /home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> # d.addPairwiseGaussian(3/scale_factor, compat=10)
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> d.addPairwiseBilateral(sxy=80 / scale_factor, srgb=13, rgbim=np.copy(img), compat=compat)
# ---> <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> Q = d.inference(t)
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> # crf = np.argmax(Q, axis=0).reshape((h, w))
#      <a href='vscode-notebook-cell:/home/yesindeed/Documents/Research/codes/ours/GazeSup/process/refine_gazemap_kvasir_ablation.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> crf = np.array(Q)[1].reshape((h, w))
#
# KeyboardInterrupt:

# %%
dice_crf_l = {}
dice_heatmap_l = {}

thres = 0.2

for i, path in tqdm(enumerate(glob.glob(os.path.join(root, "gaze", f"heatmap_{annotator}", "*.jpg")))):
    path = os.path.basename(path).split(".")[0]
    gt = np.array(Image.open(os.path.join(root, "masks", f"{path}.jpg")).convert("L"))
    heatmap = np.array(Image.open(os.path.join(root, "gaze", f"heatmap_{annotator}", f"{path}.jpg")).convert("L"))
    crf_map = np.array(Image.open(os.path.join(root, "gaze", f"crf_compat1_{annotator}", f"{path}.jpg")).convert("L"))

    heatmap = heatmap.astype(np.float32) / 255
    crf_map = crf_map.astype(np.float32) / 255

    dice_heatmap = compute_dice(heatmap > thres, gt.astype(np.float32) / 255)
    dice_crf = compute_dice(crf_map > thres, gt.astype(np.float32) / 255)

    dice_crf_l[path] = dice_crf
    dice_heatmap_l[path] = dice_heatmap

print(np.mean(list(dice_heatmap_l.values())))
print(np.mean(list(dice_crf_l.values())))
# Out:
# 500it [00:04, 101.04it/s]
# 0.6549300784362613
# 0.7224185802861915

# %%
plt.figure()
f, axes = plt.subplots(1, 5, figsize=(28, 6))

# path = "cju0roawvklrq0799vmjorwfv"
# path = "cju30ia8da2bq0799klnehml2"
# path = "cju2iatlki5u309930zmgkv6h"
# path = "cju0qoxqj9q6s0835b43399p4"
path = "cju0qx73cjw570799j4n5cjze"
# path = "cju0qx73cjw570799j4n5cjze"

# all_paths = glob.glob(
#     "/media/yesindeed/DATADRIVE1/data/Kvasir-SEG/gaze/crf_compat1/*.jpg"
# )
# path = os.path.basename(all_paths[10])[:-4]

img = np.array(Image.open(os.path.join(
    root, "images", f"{path}.jpg")).convert("RGB"))
gt = np.array(Image.open(os.path.join(
    root, "masks", f"{path}.jpg")).convert("L"))
heatmap = np.array(Image.open(os.path.join(
    root, "gaze", "heatmap", f"{path}.jpg")).convert("L")) / 255
heatmap_new = (
    np.array(Image.open(os.path.join(root, "gaze",
             f"heatmap_{annotator}", f"{path}.jpg")).convert("L")) / 255
)
# crf_map_05 = (
#     np.array(
#         Image.open(os.path.join(root, "gaze", "crf_compat0.5", f"{path}.jpg")).convert(
#             "L"
#         )
#     )
#     / 255
# )
crf_map_10 = (
    np.array(Image.open(os.path.join(root, "gaze",
             f"crf_compat1_{annotator}", f"{path}.jpg")).convert("L")) / 255
)
# crf_map_25 = (
#     np.array(
#         Image.open(os.path.join(root, "gaze", "crf_compat2.5", f"{path}.jpg")).convert(
#             "L"
#         )
#     )
#     / 255
# )

# num 10, ck2da7fwcjfis07218r1rvm95
print(path)

for ax in axes:
    ax.axis("off")

axes[0].imshow(img)

axes[1].imshow(img)
axes[1].imshow(gt, alpha=0.4)

# axes[2].imshow(img)
# axes[2].imshow(heatmap, alpha=0.4)

axes[2].imshow(img)
axes[2].imshow(heatmap, alpha=0.4)

axes[3].imshow(img)
axes[3].imshow(heatmap_new > 0.5, alpha=0.4)

axes[4].imshow(img)
axes[4].imshow(crf_map_10 > 0.5, alpha=0.4)

# axes[4].imshow(img)
# axes[4].imshow(crf_map > 0.5, alpha=0.4)

f.tight_layout()
# Out:
# cju0qx73cjw570799j4n5cjze
